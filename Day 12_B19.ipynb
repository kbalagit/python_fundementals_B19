# %%
def describe_pet(animal_type,pet_name):
    print(f"\n I have a {animal_type}")
    print(f" my {animal_type}'s name is {pet_name}")

# %%
describe_pet('dog','bruno')
# Out:
#  I have a dog
#  my dog's name is bruno

# %%
describe_pet('rex','dog')
# Out:
#  I have a rex
#  my rex's name is dog

# %%
describe_pet('dog','Bush')
# Out:
#  I have a dog
#  my dog's name is Bush

# %%
postional arguments: by default the function would be accepting the arguments as the order of parameters declared.

# %%
describe_pet('rex','dog')
# Out:
#  I have a rex
#  my rex's name is dog

# %%
keyword arguments: by using keywords we can keep the place of our choice
    and 
    we can execute our program successfully.

# %%
def describe_pet(animal_type='dog',pet_name):
    print(f"\n I have a {animal_type}")
    print(f" my {animal_type}'s name is {pet_name}")
# Out:
#   File "<ipython-input-31-b3e38745523b>", line 1
#     def describe_pet(animal_type='dog',pet_name):
#                     ^
# SyntaxError: non-default argument follows default argument

# %%
# error because animal_type should no tbe used at the front

# %%
#below code animal_type has been used at the last in the funciton first line

# %%
def describe_pet(pet_name,animal_type='dog'):
    print(f"\n I have a {animal_type}")
    print(f" my {animal_type}'s name is {pet_name}")

# %%
describe_pet('tom')
# Out:
#  I have a dog
#  my dog's name is tom

# %%
describe_pet('snowball','cat')
# Out:
#  I have a cat
#  my cat's name is snowball

# %%
default arguments: when ever we are having a missing information, default aruguments
    will be involved and it will be executing the code

# %%
understanding the arbitary arguments:
    we are not sure,how many parameters we can pass

# %%
def make_pizza(topping):
    """taking the order of toping"""
    print(topping)

# %%
make_pizza('corn','olives','flakes')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-34396aeb5c61> in <module>
# ----> 1 make_pizza('corn','olives','flakes')
#
# TypeError: make_pizza() takes 1 positional argument but 3 were given

# %%
def make_pizza(*topping):
    print(topping)
    make_pizza('corn','olives','flakes')

# %%
make_pizza("topping")
# Out:
# ('topping',)
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ('corn', 'olives', 'flakes')
# ...

# %%
def make_Infra(storge):
    print('Netapp','EMC','Hitachi')
